# %% [markdown]
# # Visualization / Preprocessing

# %%
#Import the Numpy and Panda libraries.
import pandas as pd
import numpy as np

# %%
#Load the ‘employee_data.csv’ dataset.
employee=pd.read_csv('employee_data.csv')

# %%
#Obtain the dataset’s dimensions (number of instances/number of features).
employee.shape
# Out:
# (14249, 10)

# %%
#info
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14249 entries, 0 to 14248
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    14249 non-null  int64
#  1   department         13540 non-null  object
#  2   filed_complaint    2058 non-null   float64
#  3   last_evaluation    12717 non-null  float64
#  4   n_projects         14249 non-null  int64
#  5   recently_promoted  300 non-null    float64
#  6   salary             14249 non-null  object
#  7   satisfaction       14068 non-null  float64
#  8   status             14249 non-null  object
#  9   tenure             14068 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.1+ MB

# %%
#Check if the dataset contains missing data.
employee.isnull().sum()
# Out:
# avg_monthly_hrs          0
# department             709
# filed_complaint      12191
# last_evaluation       1532
# n_projects               0
# recently_promoted    13949
# salary                   0
# satisfaction           181
# status                   0
# tenure                 181
# dtype: int64

# %%
#Identify the unique values of the categorical feature (ocean_proximity).
housing['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
#Get the main statistics of numerical features.
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#Plot the histograms (bins=50) of numerical variables.
import matplotlib as mpl
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
#Scatter plot longitude/latitude, representing the main categories of “median_house_value” with different colors.
import seaborn as sb
sb.relplot(data=housing,x='latitude',y='longitude',hue='median_house_value')

# %%
#Calculate and sort descending the correlation coefficients between the several features and the label “median_house_value”.
housing.corr()
#deve usarse
#housing.iloc[:,:9].corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
#Pairplot the features “media_income”, “total_rooms”, “housing_median_age” as well as the label “median_house_value”.
sb.pairplot(data=housing[['median_income','total_rooms','housing_median_age','median_house_value']],  plot_kws=dict(alpha=0.1))

# %%
#Create a correlation heatmap. Conclusions?
correlation=sb.heatmap(housing.corr())
#correlation['median_house_value'].order

# %% [markdown]
# ## conclusions
# - longitude and latitude high negatively correlated
# - total bedrooms and total_rooms high correlated
# - median_income high possitive correlated with median_house_value

# %%
# 12. Create a training dataset and a test set based on a random split 80%/20%.
from sklearn.model_selection import train_test_split
train, test = train_test_split(housing,test_size=0.2,random_state=123)

# %%
#Obtain the dimensions (number of instances/number of features) of both datasets.
train.shape
# Out:
# (16512, 10)

# %%
test.shape
# Out:
# (4128, 10)

# %%
#14. Based on the training dataset, create two data frames: i) labels (train_labels); ii) only features (train_features).
y=housing.pop('median_house_value')

# %%
x=housing

# %%
y.shape
# Out:
# (20640,)

# %%
x.shape
# Out:
# (20640, 9)

# %%
#15. Isolate the numerical features (train_instances_num).
x_numerical= x.iloc[:,:8]

# %%
x_numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
#16. Impute the missing values based on the median value.
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(strategy='mean')
X=imp_mean.fit_transform(x_numerical)
x_numerical=pd.DataFrame(X,columns=x_numerical,index=x_numerical.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17104/1762644162.py in <module>
#       3 imp_mean = SimpleImputer(strategy='mean')
#       4 X=imp_mean.fit_transform(x_numerical)
# ----> 5 x_numerical=pd.DataFrame(X,columns=x_numerical,index=x_numerical.index)
#
# ~\anaconda3\envs\myenvbatina2\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     692                 )
#     693             else:
# --> 694                 mgr = ndarray_to_mgr(
#     695                     data,
#     696                     index,
#
# ~\anaconda3\envs\myenvbatina2\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     345
#     346     # _prep_ndarray ensures that values.ndim == 2 at this point
# --> 347     index, columns = _get_axes(
# ...

# %%
#Create train_instances_cat with the values of “ocean_proximity” feature. Encode (Ordinal Encoder) the respective values.
from sklearn.preprocessing import OrdinalEncoder
train_instances_cat= x['ocean_proximity']
new_ord_encoder=OrdinalEncoder()
X=new_ord_encoder.fit_transform(x)
train_instances_cat=pd.DataFrame(X,columns=train_instances_cat,index=train_instances_cat.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17104/3619959012.py in <module>
#       4 new_ord_encoder=OrdinalEncoder()
#       5 X=new_ord_encoder.fit_transform(x)
# ----> 6 train_instances_cat=pd.DataFrame(X,columns=train_instances_cat,index=train_instances_cat.index)
#
# ~\anaconda3\envs\myenvbatina2\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     692                 )
#     693             else:
# --> 694                 mgr = ndarray_to_mgr(
#     695                     data,
#     696                     index,
#
# ~\anaconda3\envs\myenvbatina2\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     349     )
#     350
# --> 351     _check_values_indices_shape_match(values, index, columns)
#     352
# ...

# %%
# Out:
# RangeIndex(start=0, stop=20640, step=1)
